# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import Normalizer

# %%
df = pd.read_csv("data.csv")
names = list(df)

# %%
def add_value_label(x_list,y_list):
    for i in range(len(x_list)):
        plt.text(i, y_list[i], y_list[i], size=16)

# %%
num_yes = len(df[df['Bankrupt?'] == 1])
num_no = len(df[df['Bankrupt?'] == 0])

# %%
plt.bar(['YES', 'NO'], [num_yes, num_no], color=['red', 'green'])
add_value_label(['YES', 'NO'], [num_yes, num_no])

# %% [markdown]
# ## Normalize data

# %%
arr = df.iloc[:,1:].to_numpy()  # bez kolumny "Bankrupt?"

# sklearn.preprocessing.Normalizer działa na wierszach, dlatego transponujemy arr
arr = np.swapaxes(arr, 0, 1)
normalizer = Normalizer().fit(arr)

# %%
arr_norm = normalizer.transform(arr)
arr_norm = np.swapaxes(arr_norm, 0, 1)

# %%
data_norm = pd.DataFrame(arr_norm, columns=names[1:])
data_norm.insert(0, "Bankrupt?", df.iloc[:,0])

# %%
data_norm.iloc[:,:20]
data_norm.iloc[:,20:40]
#data_norm.iloc[:,40:60]
#data_norm.iloc[:,60:80]
#data_norm.iloc[:,80:]
#df.iloc[:,20:40]
# Out:
#        Cash Flow Per Share   Revenue Per Share (Yuan ¥)  \
# 0                 0.011650                 4.111470e-12
# 1                 0.011892                 4.950762e-12
# 2                 0.011480                 1.391738e-12
# 3                 0.012024                 3.364252e-12
# 4                 0.011931                 6.951607e-12
# ...                    ...                          ...
# 6814              0.011998                 4.862230e-12
# 6815              0.011897                 5.396969e-12
# 6816              0.012143                 1.036190e-11
# 6817              0.012955                 7.383648e-12
# 6818              0.011431                 1.558180e-13
#
#        Operating Profit Per Share (Yuan ¥)  \
# 0                                 0.010315
# 1                                 0.010079
# 2                                 0.009930
# 3                                 0.008362
# 4                                 0.010420
# ...                                    ...
# 6814                              0.010560
# 6815                              0.010604
# 6816                              0.010762
# 6817                              0.012022
# 6818                              0.009947
#
#        Per Share Net profit before tax (Yuan ¥)  \
# 0                                      0.008969
# 1                                      0.010985
# 2                                      0.009232
# 3                                      0.009607
# 4                                      0.010887
# ...                                         ...
# 6814                                   0.011126
# 6815                                   0.011170
# 6816                                   0.011199
# 6817                                   0.011998
# 6818                                   0.011774
#
#        Realized Sales Gross Profit Growth Rate   Operating Profit Growth Rate  \
# 0                                     0.010515                       0.012112
# 1                                     0.010504                       0.012110
# 2                                     0.010827                       0.012111
# 3                                     0.010488                       0.012109
# 4                                     0.010511                       0.012113
# ...                                        ...                            ...
# 6814                                  0.010644                       0.012112
# 6815                                  0.010542                       0.012113
# 6816                                  0.010498                       0.012109
# 6817                                  0.010632                       0.012196
# 6818                                  0.012043                       0.012110
#
#        After-tax Net Profit Growth Rate   Regular Net Profit Growth Rate  \
# 0                              0.012105                         0.012104
# 1                              0.012117                         0.012117
# 2                              0.012113                         0.012113
# 3                              0.012107                         0.012107
# 4                              0.012117                         0.012117
# ...                                 ...                              ...
# 6814                           0.012119                         0.012118
# 6815                           0.012118                         0.012118
# 6816                           0.012108                         0.012108
# 6817                           0.012230                         0.012230
# 6818                           0.012114                         0.012114
#
#        Continuous Net Profit Growth Rate   Total Asset Growth Rate  \
# 0                               0.012091                  0.009690
# 1                               0.012096                  0.011889
# 2                               0.012095                  0.014165
# 3                               0.012093                  0.009495
# 4                               0.012096                  0.010721
# ...                                  ...                       ...
# 6814                            0.012097                  0.013757
# 6815                            0.012097                  0.010157
# 6816                            0.012092                  0.011655
# 6817                            0.012117                  0.014107
# 6818                            0.012095                  0.018193
#
#        Net Value Growth Rate   Total Asset Return Growth Rate Ratio  \
# 0               3.468459e-14                               0.012049
# 1               4.699612e-14                               0.012114
# 2               4.205139e-14                               0.012099
# 3               4.056638e-14                               0.012062
# 4               4.656200e-14                               0.012146
# ...                      ...                                    ...
# 6814            4.775319e-14                               0.012114
# 6815            4.725289e-14                               0.012124
# 6816            4.619406e-14                               0.012084
# 6817            5.608087e-14                               0.012109
# 6818            5.501410e-14                               0.012099
#
#        Cash Reinvestment %   Current Ratio   Quick Ratio  \
# 0                 0.011584    8.214412e-13  5.974328e-14
# 1                 0.011997    2.187711e-12  1.998129e-13
# 2                 0.011749    4.197292e-12  2.645245e-13
# 3                 0.012232    1.525112e-12  1.432790e-13
# 4                 0.012092    2.189980e-12  1.843833e-13
# ...                    ...             ...           ...
# 6814              0.012107    3.800187e-12  2.699557e-13
# 6815              0.012019    3.367001e-12  3.334638e-13
# 6816              0.012083    1.397222e-11  1.736845e-12
# 6817              0.012772    4.648177e-12  3.589226e-13
# 6818              0.011468    1.867213e-11  2.023032e-12
#
#        Interest Expense Ratio   Total debt/Total net worth   Debt ratio %  \
# 0                    0.012088                 1.528786e-12       0.020051
# 1                    0.012188                 8.987843e-13       0.016535
# 2                    0.012082                 1.527474e-12       0.020046
# 3                    0.012093                 6.881502e-13       0.014631
# 4                    0.012205                 3.701995e-13       0.010289
# ...                       ...                          ...            ...
# 6814                 0.012116                 4.784338e-13       0.012038
# 6815                 0.012118                 3.323732e-13       0.009588
# 6816                 0.012101                 1.000397e-13       0.003761
# 6817                 0.012103                 2.743554e-13       0.008402
# 6818                 0.012101                 3.317176e-14       0.001367
#
#        Net worth/Assets   Long-term fund suitability ratio (A)
# 0              0.010801                               0.002063
# 1              0.011297                               0.002077
# 2              0.010802                               0.002094
# 3              0.011566                               0.002073
# 4              0.012178                               0.002178
# ...                 ...                                    ...
# 6814           0.011932                               0.002115
# 6815           0.012277                               0.002781
# 6816           0.013099                               0.003757
# 6817           0.012445                               0.002270
# 6818           0.013437                               0.024013
#
# [6819 rows x 20 columns]

# %%
suspicious_cols = [' Operating Expense Rate',
                   ' Research and development expense rate',
                   ' Interest-bearing debt interest rate',
                   ' Revenue Per Share (Yuan ¥)',
                   ' Net Value Growth Rate',
                   ' Current Ratio',
                   ' Quick Ratio',
                   ' Total debt/Total net worth',
                   ' Accounts Receivable Turnover',
                   ' Average Collection Days',
                   ' Inventory Turnover Rate (times)',
                   ' Fixed Assets Turnover Frequency',
                   ' Revenue per person',
                   ' Allocation rate per person',
                   ' Quick Assets/Current Liability',
                   ' Cash/Current Liability',
                   ' Inventory/Current Liability',
                   ' Long-term Liability to Current Assets',
                   ' Current Asset Turnover Rate',
                   ' Quick Asset Turnover Rate',
                   ' Cash Turnover Rate',
                   ' Fixed Assets to Assets',
                   ' Total assets to GNP price'
                  ]
len(suspicious_cols)
# Out:
# 23

# %%
df_bool = df[suspicious_cols] > 1
df_bool
df[df_bool.any(axis=1)]
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6813          0                                           0.477600
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# 2                                    0.499019
# 3                                    0.451265
# 4                                    0.538432
# ...                                       ...
# 6813                                 0.531127
# 6814                                 0.539468
# 6815                                 0.538269
# 6817                                 0.559911
# 6818                                 0.570105
#
#        ROA(B) before interest and depreciation after tax  \
# 0                                              0.405750
# 1                                              0.516730
# 2                                              0.472295
# 3                                              0.457733
# 4                                              0.522298
# ...                                                 ...
# 6813                                           0.526099
# 6814                                           0.543230
# 6815                                           0.524172
# 6817                                           0.554045
# 6818                                           0.549548
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 0                    0.601457                      0.601457
# 1                    0.610235                      0.610235
# 2                    0.601450                      0.601364
# 3                    0.583541                      0.583541
# 4                    0.598783                      0.598783
# ...                       ...                           ...
# 6813                 0.595829                      0.595858
# 6814                 0.604455                      0.604462
# 6815                 0.598308                      0.598308
# 6817                 0.607850                      0.607850
# 6818                 0.627409                      0.627409
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 0                   0.998969                    0.796887
# 1                   0.998946                    0.797380
# 2                   0.998857                    0.796403
# 3                   0.998700                    0.796967
# 4                   0.998973                    0.797366
# ...                      ...                         ...
# 6813                0.998905                    0.797375
# 6814                0.998992                    0.797409
# 6815                0.998992                    0.797414
# 6817                0.999074                    0.797500
# 6818                0.998080                    0.801987
#
#        After-tax net Interest Rate  \
# 0                         0.808809
# 1                         0.809301
# 2                         0.808388
# 3                         0.808966
# 4                         0.809304
# ...                            ...
# 6813                      0.809294
# 6814                      0.809331
# 6815                      0.809327
# 6817                      0.809399
# 6818                      0.813800
#
#        Non-industry income and expenditure/revenue  ...  \
# 0                                         0.302646  ...
# 1                                         0.303556  ...
# 2                                         0.302035  ...
# 3                                         0.303350  ...
# 4                                         0.303475  ...
# ...                                            ...  ...
# 6813                                      0.303634  ...
# 6814                                      0.303510  ...
# 6815                                      0.303520  ...
# 6817                                      0.303498  ...
# 6818                                      0.313415  ...
#
#        Net Income to Total Assets   Total assets to GNP price  \
# 0                        0.716845                    0.009219
# 1                        0.795297                    0.008323
# 2                        0.774670                    0.040003
# 3                        0.739555                    0.003252
# 4                        0.795016                    0.003878
# ...                           ...                         ...
# 6813                     0.794028                    0.003475
# 6814                     0.799927                    0.000466
# 6815                     0.799748                    0.001959
# 6817                     0.811808                    0.002837
# 6818                     0.815956                    0.000707
#
#        No-credit Interval   Gross Profit to Sales  \
# 0                0.622879                0.601453
# 1                0.623652                0.610237
# 2                0.623841                0.601449
# 3                0.622929                0.583538
# 4                0.623521                0.598782
# ...                   ...                     ...
# 6813             0.623398                0.595827
# 6814             0.623620                0.604455
# 6815             0.623931                0.598306
# 6817             0.623957                0.607846
# 6818             0.626680                0.627408
#
#        Net Income to Stockholder's Equity   Liability to Equity  \
# 0                                0.827890              0.290202
# 1                                0.839969              0.283846
# 2                                0.836774              0.290189
# 3                                0.834697              0.281721
# 4                                0.839973              0.278514
# ...                                   ...                   ...
# 6813                             0.839864              0.281325
# 6814                             0.840359              0.279606
# 6815                             0.840306              0.278132
# 6817                             0.841084              0.277547
# 6818                             0.841019              0.275114
#
#        Degree of Financial Leverage (DFL)  \
# 0                                0.026601
# 1                                0.264577
# 2                                0.026555
# 3                                0.026697
# 4                                0.024752
# ...                                   ...
# 6813                             0.022309
# 6814                             0.027064
# 6815                             0.027009
# 6817                             0.026822
# 6818                             0.026793
#
#        Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 0                                              0.564050                   1
# 1                                              0.570175                   1
# 2                                              0.563706                   1
# 3                                              0.564663                   1
# 4                                              0.575617                   1
# ...                                                 ...                 ...
# 6813                                           0.571752                   1
# 6814                                           0.566193                   1
# 6815                                           0.566018                   1
# 6817                                           0.565302                   1
# 6818                                           0.565167                   1
#
#        Equity to Liability
# 0                 0.016469
# 1                 0.020794
# 2                 0.016474
# 3                 0.023982
# 4                 0.035490
# ...                    ...
# 6813              0.024803
# 6814              0.029890
# 6815              0.038284
# 6817              0.044009
# 6818              0.233902
#
# [6486 rows x 96 columns]

# %% [markdown]
# ### Clean data by rows

# %%
df_bool = df[suspicious_cols] < 1000
# df_bool
df[df_bool.all(axis=1)]
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 23            0                                           0.494857
# 84            0                                           0.474675
# 137           0                                           0.508556
# 569           0                                           0.388047
# 629           0                                           0.561010
# ...         ...                                                ...
# 6751          0                                           0.624482
# 6763          0                                           0.518452
# 6789          0                                           0.284941
# 6801          0                                           0.543948
# 6816          0                                           0.472725
#
#        ROA(A) before interest and % after tax  \
# 23                                   0.548136
# 84                                   0.534780
# 137                                  0.563727
# 569                                  0.461459
# 629                                  0.609137
# ...                                       ...
# 6751                                 0.685292
# 6763                                 0.580299
# 6789                                 0.314599
# 6801                                 0.606738
# 6816                                 0.533744
#
#        ROA(B) before interest and depreciation after tax  \
# 23                                             0.540446
# 84                                             0.527812
# 137                                            0.564859
# 569                                            0.458108
# 629                                            0.615504
# ...                                                 ...
# 6751                                           0.668826
# 6763                                           0.568874
# 6789                                           0.306119
# 6801                                           0.590021
# 6816                                           0.520638
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 23                   0.609507                      0.609507
# 84                   0.605291                      0.605291
# 137                  0.603533                      0.603533
# 569                  0.596290                      0.596290
# 629                  0.615410                      0.615410
# ...                       ...                           ...
# 6751                 0.629946                      0.629946
# 6763                 0.614004                      0.614004
# 6789                 0.605226                      0.605010
# 6801                 0.620346                      0.620346
# 6816                 0.610444                      0.610213
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 23                  0.999052                    0.797413
# 84                  0.998968                    0.797391
# 137                 0.999005                    0.797482
# 569                 0.998682                    0.795878
# 629                 0.999171                    0.797572
# ...                      ...                         ...
# 6751                0.999293                    0.797830
# 6763                0.999107                    0.797507
# 6789                0.998741                    0.796512
# 6801                0.999176                    0.797681
# 6816                0.998984                    0.797401
#
#        After-tax net Interest Rate  \
# 23                        0.809323
# 84                        0.809317
# 137                       0.809401
# 569                       0.808276
# 629                       0.809469
# ...                            ...
# 6751                      0.809675
# 6763                      0.809414
# 6789                      0.808441
# 6801                      0.809546
# 6816                      0.809317
#
#        Non-industry income and expenditure/revenue  ...  \
# 23                                        0.303392  ...
# 84                                        0.303530  ...
# 137                                       0.303609  ...
# 569                                       0.301484  ...
# 629                                       0.303420  ...
# ...                                            ...  ...
# 6751                                      0.303617  ...
# 6763                                      0.303442  ...
# 6789                                      0.302468  ...
# 6801                                      0.303600  ...
# 6816                                      0.303512  ...
#
#        Net Income to Total Assets   Total assets to GNP price  \
# 23                       0.798104                    0.018753
# 84                       0.798238                    0.000717
# 137                      0.811876                    0.007121
# 569                      0.748854                    0.000454
# 629                      0.826813                    0.000373
# ...                           ...                         ...
# 6751                     0.878025                    0.000958
# 6763                     0.824987                    0.000457
# 6789                     0.665514                    0.000298
# 6801                     0.836314                    0.001398
# 6816                     0.797778                    0.002840
#
#        No-credit Interval   Gross Profit to Sales  \
# 23               0.623486                0.609508
# 84               0.624029                0.605289
# 137              0.624679                0.603529
# 569              0.624642                0.596288
# 629              0.623344                0.615405
# ...                   ...                     ...
# 6751             0.624011                0.629945
# 6763             0.624147                0.614002
# 6789             0.624243                0.605227
# 6801             0.624129                0.620343
# 6816             0.624156                0.610441
#
#        Net Income to Stockholder's Equity   Liability to Equity  \
# 23                               0.840326              0.287134
# 84                               0.840168              0.276091
# 137                              0.841481              0.281101
# 569                              0.837758              0.275052
# 629                              0.844143              0.287221
# ...                                   ...                   ...
# 6751                             0.844724              0.276291
# 6763                             0.841683              0.276219
# 6789                             0.830563              0.278538
# 6801                             0.842457              0.276694
# 6816                             0.840138              0.275789
#
#        Degree of Financial Leverage (DFL)  \
# 23                               0.029364
# 84                               0.026827
# 137                              0.026865
# 569                              0.026791
# 629                              0.026996
# ...                                   ...
# 6751                             0.026791
# 6763                             0.026791
# 6789                             0.026774
# 6801                             0.026793
# 6816                             0.026791
#
#        Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 23                                             0.568730                   1
# 84                                             0.565324                   1
# 137                                            0.565488                   1
# 569                                            0.565156                   1
# 629                                            0.565977                   1
# ...                                                 ...                 ...
# 6751                                           0.565158                   1
# 6763                                           0.565158                   1
# 6789                                           0.565077                   1
# 6801                                           0.565166                   1
# 6816                                           0.565158                   1
#
#        Equity to Liability
# 23                0.018005
# 84                0.078900
# 137               0.025310
# 569               0.271140
# 629               0.017952
# ...                    ...
# 6751              0.070373
# 6763              0.073188
# 6789              0.035334
# 6801              0.058338
# 6816              0.097649
#
# [333 rows x 96 columns]

# %%
df_clean = df[df_bool.all(axis=1)]
num_yes = len(df_clean[df_clean['Bankrupt?'] == 1])
num_no = len(df_clean[df_clean['Bankrupt?'] == 0])

plt.bar(['YES', 'NO'], [num_yes, num_no], color=['red', 'green'])
add_value_label(['YES', 'NO'], [num_yes, num_no])

# %% [markdown]
# ### Clean data by columns

# %%
names_subset = set(names).difference(set(suspicious_cols))
df[names_subset]
df_bool = df[list(names_subset)] < 1000000
# # df_bool
df[df_bool.all(axis=1)]

# len(df[' Total Asset Growth Rate'][df[' Total Asset Growth Rate'] > 100000])
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 158           1                                           0.456101
# 217           0                                           0.544094
# 228           0                                           0.491639
# 275           0                                           0.491786
# 284           1                                           0.506362
# ...         ...                                                ...
# 6775          0                                           0.545069
# 6776          0                                           0.556038
# 6781          0                                           0.654073
# 6795          0                                           0.628528
# 6810          0                                           0.578901
#
#        ROA(A) before interest and % after tax  \
# 158                                  0.520715
# 217                                  0.609954
# 228                                  0.542357
# 275                                  0.555931
# 284                                  0.565689
# ...                                       ...
# 6775                                 0.612298
# 6776                                 0.613716
# 6781                                 0.706662
# 6795                                 0.691616
# 6810                                 0.648005
#
#        ROA(B) before interest and depreciation after tax  \
# 158                                            0.510895
# 217                                            0.583436
# 228                                            0.539643
# 275                                            0.543498
# 284                                            0.561914
# ...                                                 ...
# 6775                                           0.598854
# 6776                                           0.598480
# 6781                                           0.689116
# 6795                                           0.670539
# 6810                                           0.631725
#
#        Operating Gross Margin   Realized Sales Gross Margin  \
# 158                  0.597630                      0.597818
# 217                  0.601753                      0.601753
# 228                  0.600153                      0.600153
# 275                  0.600513                      0.600513
# 284                  0.600218                      0.600218
# ...                       ...                           ...
# 6775                 0.605817                      0.604599
# 6776                 0.634183                      0.633434
# 6781                 0.610293                      0.610300
# 6795                 0.607460                      0.607460
# 6810                 0.602841                      0.602841
#
#        Operating Profit Rate   Pre-tax net Interest Rate  \
# 158                 0.998938                    0.797333
# 217                 0.999007                    0.797576
# 228                 0.999005                    0.797402
# 275                 0.998988                    0.797395
# 284                 0.999061                    0.797442
# ...                      ...                         ...
# 6775                0.999014                    0.797742
# 6776                0.999234                    0.797692
# 6781                0.999135                    0.797662
# 6795                0.999145                    0.797759
# 6810                0.999026                    0.797490
#
#        After-tax net Interest Rate  \
# 158                       0.809271
# 217                       0.809450
# 228                       0.809328
# 275                       0.809318
# 284                       0.809412
# ...                            ...
# 6775                      0.809626
# 6776                      0.809547
# 6781                      0.809527
# 6795                      0.809613
# 6810                      0.809402
#
#        Non-industry income and expenditure/revenue  ...  \
# 158                                       0.303491  ...
# 217                                       0.303770  ...
# 228                                       0.303471  ...
# 275                                       0.303494  ...
# 284                                       0.303423  ...
# ...                                            ...  ...
# 6775                                      0.304046  ...
# 6776                                      0.303500  ...
# 6781                                      0.303655  ...
# 6795                                      0.303802  ...
# 6810                                      0.303580  ...
#
#        Net Income to Total Assets   Total assets to GNP price  \
# 158                      0.789400                    0.001480
# 217                      0.832166                    0.003382
# 228                      0.798385                    0.004416
# 275                      0.803782                    0.001703
# 284                      0.818788                    0.005197
# ...                           ...                         ...
# 6775                     0.834617                    0.002530
# 6776                     0.836948                    0.000398
# 6781                     0.870631                    0.002282
# 6795                     0.868035                    0.002702
# 6810                     0.846995                    0.000995
#
#        No-credit Interval   Gross Profit to Sales  \
# 158              0.623399                0.597631
# 217              0.623710                0.601750
# 228              0.629794                0.600148
# 275              0.623673                0.600509
# 284              0.624313                0.600213
# ...                   ...                     ...
# 6775             0.624115                0.605816
# 6776             0.624005                0.634183
# 6781             0.624180                0.610294
# 6795             0.624386                0.607460
# 6810             0.624040                0.602840
#
#        Net Income to Stockholder's Equity   Liability to Equity  \
# 158                              0.839201              0.286551
# 217                              0.842439              0.277611
# 228                              0.840347              0.286181
# 275                              0.841175              0.288932
# 284                              0.844107              0.293720
# ...                                   ...                   ...
# 6775                             0.843064              0.279336
# 6776                             0.842745              0.277574
# 6781                             0.844899              0.277443
# 6795                             0.845679              0.279340
# 6810                             0.844588              0.280905
#
#        Degree of Financial Leverage (DFL)  \
# 158                              0.026478
# 217                              0.026859
# 228                              0.028791
# 275                              0.027475
# 284                              0.027237
# ...                                   ...
# 6775                             0.026827
# 6776                             0.026791
# 6781                             0.026793
# 6795                             0.026791
# 6810                             0.026813
#
#        Interest Coverage Ratio (Interest expense to EBIT)   Net Income Flag  \
# 158                                            0.563037                   1
# 217                                            0.565461                   1
# 228                                            0.568455                   1
# 275                                            0.567138                   1
# 284                                            0.566653                   1
# ...                                                 ...                 ...
# 6775                                           0.565322                   1
# 6776                                           0.565158                   1
# 6781                                           0.565169                   1
# 6795                                           0.565158                   1
# 6810                                           0.565259                   1
#
#        Equity to Liability
# 158               0.018387
# 217               0.043278
# 228               0.018650
# 275               0.017024
# 284               0.015316
# ...                    ...
# 6775              0.031029
# 6776              0.043696
# 6781              0.045285
# 6795              0.031012
# 6810              0.025787
#
# [803 rows x 96 columns]

# %%
# names_subset.remove(' Total Asset Growth Rate')
names_subset.remove(' Net Income Flag')  # all companies have value=1
df_bool = df[list(names_subset)] < 1000
df_clean = df[list(names_subset)][df_bool.all(axis=1)]
df_clean
# Out:
#        ROA(A) before interest and % after tax   Net worth/Assets  \
# 0                                    0.424389           0.792424
# 1                                    0.538214           0.828824
# 2                                    0.499019           0.792484
# 3                                    0.451265           0.848535
# 4                                    0.538432           0.893491
# ...                                       ...                ...
# 6814                                 0.539468           0.875382
# 6815                                 0.538269           0.900747
# 6816                                 0.533744           0.961061
# 6817                                 0.559911           0.913021
# 6818                                 0.570105           0.985851
#
#        Current Liability to Assets   Inventory/Working Capital  \
# 0                         0.147308                    0.276920
# 1                         0.056963                    0.289642
# 2                         0.098162                    0.277456
# 3                         0.098715                    0.276580
# 4                         0.110195                    0.287913
# ...                            ...                         ...
# 6814                      0.103838                    0.277543
# 6815                      0.089901                    0.277368
# 6816                      0.024414                    0.277022
# 6817                      0.083199                    0.277353
# 6818                      0.018517                    0.276975
#
#        Interest Expense Ratio   Operating Funds to Liability  \
# 0                    0.629951                       0.334015
# 1                    0.635172                       0.341106
# 2                    0.629631                       0.336731
# 3                    0.630228                       0.348716
# 4                    0.636055                       0.344639
# ...                       ...                            ...
# 6814                 0.631415                       0.346224
# 6815                 0.631489                       0.342166
# 6816                 0.630612                       0.358847
# 6817                 0.630731                       0.380251
# 6818                 0.630618                       0.239585
#
#        Total expense/Assets   Current Liabilities/Liability  \
# 0                  0.064856                        0.676269
# 1                  0.025516                        0.308589
# 2                  0.021387                        0.446027
# 3                  0.024161                        0.615848
# 4                  0.026385                        0.975007
# ...                     ...                             ...
# 6814               0.019060                        0.786888
# 6815               0.011118                        0.849898
# 6816               0.035446                        0.553964
# 6817               0.016443                        0.893241
# 6818               0.006089                        1.000000
#
#        Total Asset Turnover   Net Value Per Share (B)  ...  \
# 0                  0.086957                  0.147950  ...
# 1                  0.064468                  0.182251  ...
# 2                  0.014993                  0.177911  ...
# 3                  0.089955                  0.154187  ...
# 4                  0.175412                  0.167502  ...
# ...                     ...                       ...  ...
# 6814               0.103448                  0.175045  ...
# 6815               0.103448                  0.181324  ...
# 6816               0.106447                  0.269521  ...
# 6817               0.109445                  0.213392  ...
# 6818               0.002999                  0.220766  ...
#
#        Equity to Liability   Cash Flow to Equity  \
# 0                 0.016469              0.312905
# 1                 0.020794              0.314163
# 2                 0.016474              0.314515
# 3                 0.023982              0.302382
# 4                 0.035490              0.311567
# ...                    ...                   ...
# 6814              0.029890              0.314063
# 6815              0.038284              0.314446
# 6816              0.097649              0.313353
# 6817              0.044009              0.320118
# 6818              0.233902              0.316238
#
#        Interest Coverage Ratio (Interest expense to EBIT)  \
# 0                                              0.564050
# 1                                              0.570175
# 2                                              0.563706
# 3                                              0.564663
# 4                                              0.575617
# ...                                                 ...
# 6814                                           0.566193
# 6815                                           0.566018
# 6816                                           0.565158
# 6817                                           0.565302
# 6818                                           0.565167
#
#        Realized Sales Gross Profit Growth Rate  \
# 0                                     0.022102
# 1                                     0.022080
# 2                                     0.022760
# 3                                     0.022046
# 4                                     0.022096
# ...                                        ...
# 6814                                  0.022374
# 6815                                  0.022159
# 6816                                  0.022068
# 6817                                  0.022350
# 6818                                  0.025316
#
#        Inventory and accounts receivable/Net value  \
# 0                                         0.398036
# 1                                         0.397725
# 2                                         0.406580
# 3                                         0.397925
# 4                                         0.400079
# ...                                            ...
# 6814                                      0.404804
# 6815                                      0.399926
# 6816                                      0.395592
# 6817                                      0.401540
# 6818                                      0.393883
#
#        ROA(C) before interest and depreciation before interest  \
# 0                                              0.370594
# 1                                              0.464291
# 2                                              0.426071
# 3                                              0.399844
# 4                                              0.465022
# ...                                                 ...
# 6814                                           0.493687
# 6815                                           0.475162
# 6816                                           0.472725
# 6817                                           0.506264
# 6818                                           0.493053
#
#        Non-industry income and expenditure/revenue  \
# 0                                         0.302646
# 1                                         0.303556
# 2                                         0.302035
# 3                                         0.303350
# 4                                         0.303475
# ...                                            ...
# 6814                                      0.303510
# 6815                                      0.303520
# 6816                                      0.303512
# 6817                                      0.303498
# 6818                                      0.313415
#
#        Current Liabilities/Equity  \
# 0                        0.339077
# 1                        0.329740
# 2                        0.334777
# 3                        0.331509
# 4                        0.330726
# ...                           ...
# 6814                     0.330914
# 6815                     0.329753
# 6816                     0.326921
# 6817                     0.329294
# 6818                     0.326690
#
#        ROA(B) before interest and depreciation after tax  \
# 0                                              0.405750
# 1                                              0.516730
# 2                                              0.472295
# 3                                              0.457733
# 4                                              0.522298
# ...                                                 ...
# 6814                                           0.543230
# 6815                                           0.524172
# 6816                                           0.520638
# 6817                                           0.554045
# 6818                                           0.549548
#
#        Long-term fund suitability ratio (A)
# 0                                  0.005024
# 1                                  0.005059
# 2                                  0.005100
# 3                                  0.005047
# 4                                  0.005303
# ...                                     ...
# 6814                               0.005150
# 6815                               0.006772
# 6816                               0.009149
# 6817                               0.005529
# 6818                               0.058476
#
# [6819 rows x 71 columns]

# %%
num_yes = len(df_clean[df_clean['Bankrupt?'] == 1])
num_no = len(df_clean[df_clean['Bankrupt?'] == 0])

plt.bar(['YES', 'NO'], [num_yes, num_no], color=['red', 'green'])
add_value_label(['YES', 'NO'], [num_yes, num_no])

# %% [markdown]
# # Clustering algorithms

# %%
attr = names_subset
attr.remove('Bankrupt?')
cl = ['Bankrupt?']

# %%
X = df_clean[attr]
Y = df_clean[cl].to_numpy()

# %%
Y = Y.reshape(len(Y))

# %% [markdown]
# ## k-means

# %%
from sklearn.cluster import KMeans
from sklearn import metrics
from sklearn.metrics.pairwise import pairwise_distances_argmin

# %%
def calculate_stats(labels_pred, labels_true):
    print("Homogeneity: %0.3f" % metrics.homogeneity_score(labels_true, labels_pred))
    print("Completeness: %0.3f" % metrics.completeness_score(labels_true, labels_pred))
    print('Rand Score: %0.3f' % metrics.rand_score(labels_true, labels_pred))
    print('Adjusted Rand Score: %0.3f' % metrics.adjusted_rand_score(labels_true, labels_pred))
    print('\nPair Confusion Matrix: \n\n', metrics.pair_confusion_matrix(labels_true, labels_pred))

# %% [markdown]
# ![obraz.png](attachment:obraz.png)

# %%
def train_k_means(X, Y):
    k_means = KMeans(init="k-means++", n_clusters=2, n_init=5)
    k_means.fit(X)
    k_means_cluster_centers = k_means.cluster_centers_
    k_means_labels = pairwise_distances_argmin(X, k_means_cluster_centers)
    print(np.unique(k_means_labels, return_counts=True), end="\n\n")
    calculate_stats(k_means_labels, Y)

# %%
train_k_means(X, Y)
# Out:
# (array([0, 1], dtype=int64), array([3117, 3702], dtype=int64))
#
# Homogeneity: 0.008
# Completeness: 0.002
# Rand Score: 0.505
# Adjusted Rand Score: 0.003
#
# Pair Confusion Matrix:
#
#  [[ 1476780  1426780]
#  [21601488 21986894]]

# %%
expected = np.array([])
predicted = np.array([])

# %% [markdown]
# ## Hierarchical clustering

# %%
from sklearn.cluster import AgglomerativeClustering

# %%
def train_hierarchical(X, Y):
    agglom = AgglomerativeClustering(n_clusters=2, linkage="ward").fit(X)
    print(np.unique(agglom.labels_, return_counts=True), end="\n\n")
    calculate_stats(agglom.labels_, Y)

# %%
train_hierarchical(X, Y)
# Out:
# (array([0, 1], dtype=int64), array([4683, 2136], dtype=int64))
#
# Homogeneity: 0.000
# Completeness: 0.000
# Rand Score: 0.561
# Adjusted Rand Score: 0.000
#
# Pair Confusion Matrix:
#
#  [[ 1254420  1649140]
#  [18751356 24837026]]

# %%
from sklearn.neighbors import kneighbors_graph

# %%
def train_hierarchical2(X, Y):
    connectivity = kneighbors_graph(X, n_neighbors=10, include_self=False)
    agglom2 = AgglomerativeClustering(n_clusters=2, connectivity=connectivity, linkage="ward").fit(X)
    print(np.unique(agglom2.labels_, return_counts=True), end="\n")
    calculate_stats(agglom2.labels_, Y)

# %%
train_hierarchical2(X, Y)
# Out:
# (array([0, 1], dtype=int64), array([5631, 1188], dtype=int64))
# Homogeneity: 0.004
# Completeness: 0.001
# Rand Score: 0.691
# Adjusted Rand Score: 0.018
#
# Pair Confusion Matrix:
#
#  [[  966708  1936852]
#  [12412548 31175834]]

# %% [markdown]
# ## DBSCAN

# %%
from sklearn.cluster import DBSCAN

# %%
def train_dbscan(X, Y):
    db = DBSCAN(eps=0.35, min_samples=50).fit(X)
    print(np.unique(db.labels_, return_counts=True), end="\n\n")
    calculate_stats(db.labels_, Y)

# %%
train_dbscan(X, Y)
# Out:
# (array([-1,  0], dtype=int64), array([ 264, 6555], dtype=int64))
#
# Homogeneity: 0.015
# Completeness: 0.013
# Rand Score: 0.882
# Adjusted Rand Score: 0.074
#
# Pair Confusion Matrix:
#
#  [[  435030  2468530]
#  [ 3026010 40562372]]

# %% [markdown]
# ## OPTICS

# %%
from sklearn.cluster import OPTICS

# %%
def train_optics(X, Y):
    clust = OPTICS(min_samples=50, xi=0.05, min_cluster_size=0.05)
    clust.fit(X)
    print(np.unique(clust.labels_, return_counts=True), end="\n\n")
    calculate_stats(clust.labels_, Y)

# %%
#train_optics(X, Y)

# %% [markdown]
# ## PCA

# %%
from sklearn.decomposition import PCA

# %%
def plot_pca2(pca2_):
    fig = plt.figure(figsize = (10,10))
    ax = fig.add_subplot(1,1,1) 
    ax.set_xlabel('PC1', fontsize = 15)
    ax.set_ylabel('PC2', fontsize = 15)
    ax.set_title('2 component PCA', fontsize = 20)

    bankrupt_idx = pca2_['y'] == 1
    non_bankrupt_idx = pca2_['y'] == 0

    ax.scatter(pca2_.loc[bankrupt_idx, 'pc1'], pca2_.loc[bankrupt_idx, 'pc2'], c = 'r', s = 15, marker='s')
    ax.scatter(pca2_.loc[non_bankrupt_idx, 'pc1'], pca2_.loc[non_bankrupt_idx, 'pc2'], c = 'b', s = 5)

    ax.legend(['Bankrupt', 'Non-bankrupt'])
    ax.grid()
    
def plot_pca3(pca3_):
    fig = plt.figure(figsize = (12,12))
    ax = fig.add_subplot(projection='3d')
    ax.set_xlabel('PC1', fontsize = 15)
    ax.set_ylabel('PC2', fontsize = 15)
    ax.set_zlabel('PC3', fontsize = 15)
    ax.set_title('3 component PCA', fontsize = 20)

    bankrupt_idx = pca3_['y'] == 1
    non_bankrupt_idx = pca3_['y'] == 0

    ax.scatter(pca3_.loc[bankrupt_idx, 'pc1'], pca3_.loc[bankrupt_idx, 'pc2'], pca3_.loc[bankrupt_idx, 'pc3'], c='r', s=15, marker='s')
    ax.scatter(pca3_.loc[non_bankrupt_idx, 'pc1'], pca3_.loc[non_bankrupt_idx, 'pc2'], pca3_.loc[non_bankrupt_idx, 'pc3'], c='b', s=5)

    ax.legend(['Bankrupt', 'Non-bankrupt'])
    ax.grid()

# %% [markdown]
# ### PCA 2 components

# %%
def pca2(X, Y):
    pca = PCA(n_components=2)
    principalComponents = pca.fit_transform(X)
    pca2 = pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2'])
    pca2_ = pd.concat([pca2, pd.DataFrame(Y, columns = ['y'])], axis = 1)
    plot_pca2(pca2_)
pca2(X, Y)

# %% [markdown]
# ### PCA 3 components

# %%
def pca3(X, Y):
    pca = PCA(n_components=3)
    principalComponents = pca.fit_transform(X)
    pca3 = pd.DataFrame(data = principalComponents, columns = ['pc1', 'pc2', 'pc3'])
    pca3_ = pd.concat([pca3, pd.DataFrame(Y, columns = ['y'])], axis = 1)
    plot_pca3(pca3_)
pca3(X, Y)

# %% [markdown]
# ## Undersampling

# %%
data = df_clean[df_clean['Bankrupt?'] == 1]
data = pd.concat([data, df_clean[df_clean['Bankrupt?'] == 0].sample(n=220)])

num_yes = len(data[data['Bankrupt?'] == 1])
num_no = len(data[data['Bankrupt?'] == 0])

plt.bar(['YES', 'NO'], [num_yes, num_no], color=['red', 'green'])
add_value_label(['YES', 'NO'], [num_yes, num_no])

# %%
pca2(data[attr], data[cl].to_numpy())

# %%
pca3(data[attr], data[cl].to_numpy())

# %% [markdown]
# ## k-means

# %%
train_k_means(data[attr], data[cl].to_numpy().reshape(len(data)))
# Out:
# (array([0, 1], dtype=int64), array([193, 247], dtype=int64))
#
# Homogeneity: 0.002
# Completeness: 0.002
# Rand Score: 0.500
# Adjusted Rand Score: 0.000
#
# Pair Confusion Matrix:
#
#  [[47792 49008]
#  [47550 48810]]

# %% [markdown]
# ## Hierarchical

# %%
train_hierarchical(data[attr], data[cl].to_numpy().reshape(len(data)))
# Out:
# (array([0, 1], dtype=int64), array([200, 240], dtype=int64))
#
# Homogeneity: 0.027
# Completeness: 0.027
# Rand Score: 0.517
# Adjusted Rand Score: 0.034
#
# Pair Confusion Matrix:
#
#  [[49764 47036]
#  [46236 50124]]

# %%
train_hierarchical2(data[attr], data[cl].to_numpy().reshape(len(data)))
# Out:
# (array([0, 1], dtype=int64), array([200, 240], dtype=int64))
# Homogeneity: 0.027
# Completeness: 0.027
# Rand Score: 0.517
# Adjusted Rand Score: 0.034
#
# Pair Confusion Matrix:
#
#  [[49764 47036]
#  [46236 50124]]

# %% [markdown]
# ## DBSCAN

# %%
train_dbscan(data[attr], data[cl].to_numpy().reshape(len(data)))
# Out:
# (array([-1,  0], dtype=int64), array([116, 324], dtype=int64))
#
# Homogeneity: 0.000
# Completeness: 0.000
# Rand Score: 0.499
# Adjusted Rand Score: -0.002
#
# Pair Confusion Matrix:
#
#  [[37588 59212]
#  [37580 58780]]

# %% [markdown]
# ## Neural Network

# %%
import tensorflow as tf
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report, f1_score
from tensorflow.keras import regularizers

# %%
def nn(X, y, val_ratio=0.3, name='default', lr=0.001):
    global results
    
    # split data
    while True:
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = val_ratio) 
        if all(np.unique(y_test, return_counts=True)[1] > 50):
            break
    
    opt = tf.keras.optimizers.Adam(learning_rate=lr)
    
    # model
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Dense(64, input_shape=(70,), activity_regularizer=regularizers.L2(0.00001), activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(128, activity_regularizer=regularizers.L2(0.00001), activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(256, activity_regularizer=regularizers.L2(0.00001), activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(512, activity_regularizer=regularizers.L2(0.00001), activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(1024, activity_regularizer=regularizers.L2(0.00001), activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(1024, activity_regularizer=regularizers.L2(0.00001), activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(512, input_shape=(70,), activity_regularizer=regularizers.L2(0.00001), activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(256, activity_regularizer=regularizers.L2(0.00001), activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(128, activity_regularizer=regularizers.L2(0.00001), activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(64, activity_regularizer=regularizers.L2(0.00001), activation='relu'))
    model.add(tf.keras.layers.Dropout(0.2))
    
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))
    model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['binary_accuracy', 'AUC'])
    model.fit(X_train.to_numpy(), y_train.to_numpy(), 
              validation_data=(X_test, y_test), batch_size=32, epochs=50)
    
    y_pred = model.predict(X_test)
    # print(np.round(y_pred))
    matrix = confusion_matrix(y_test.to_numpy(), np.round(y_pred))
    print("\nConfusion matrix: \n", matrix)
    
    f1 = f1_score(y_test.to_numpy(), np.round(y_pred), zero_division=1)
    # results[len(results.items())] = ['Neural_Network' + name, f1, len(y)]
    print("\nF1 Score:", f1)
    return model

# %%
# Y = pd.DataFrame(Y, columns=['Y'])

# %%
# nn(df_clean[attr], df_clean[cl], lr=0.001)
model_nn = nn(data[attr], data[cl], lr=0.0003)
# Out:
# Epoch 1/50
# 10/10 [==============================] - 2s 56ms/step - loss: 0.6951 - binary_accuracy: 0.4903 - auc: 0.4858 - val_loss: 0.6941 - val_binary_accuracy: 0.4697 - val_auc: 0.5000
# Epoch 2/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.6913 - binary_accuracy: 0.5000 - auc: 0.5492 - val_loss: 0.6971 - val_binary_accuracy: 0.4697 - val_auc: 0.6643
# Epoch 3/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.6973 - binary_accuracy: 0.5065 - auc: 0.4860 - val_loss: 0.6952 - val_binary_accuracy: 0.4697 - val_auc: 0.6507
# Epoch 4/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.6975 - binary_accuracy: 0.4838 - auc: 0.4559 - val_loss: 0.6933 - val_binary_accuracy: 0.4697 - val_auc: 0.5071
# Epoch 5/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6911 - binary_accuracy: 0.5097 - auc: 0.5327 - val_loss: 0.6945 - val_binary_accuracy: 0.4697 - val_auc: 0.7714
# Epoch 6/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.6969 - binary_accuracy: 0.5097 - auc: 0.4773 - val_loss: 0.6942 - val_binary_accuracy: 0.4697 - val_auc: 0.7571
# Epoch 7/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.6926 - binary_accuracy: 0.4935 - auc: 0.5196 - val_loss: 0.6924 - val_binary_accuracy: 0.4697 - val_auc: 0.8025
# Epoch 8/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6904 - binary_accuracy: 0.5325 - auc: 0.5452 - val_loss: 0.6916 - val_binary_accuracy: 0.4697 - val_auc: 0.8062
# Epoch 9/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.6903 - binary_accuracy: 0.5292 - auc: 0.5457 - val_loss: 0.6903 - val_binary_accuracy: 0.4697 - val_auc: 0.8293
# Epoch 10/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.6951 - binary_accuracy: 0.4935 - auc: 0.4726 - val_loss: 0.6886 - val_binary_accuracy: 0.5000 - val_auc: 0.8362
# Epoch 11/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.6953 - binary_accuracy: 0.5227 - auc: 0.5126 - val_loss: 0.6854 - val_binary_accuracy: 0.4697 - val_auc: 0.8752
# Epoch 12/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.6901 - binary_accuracy: 0.5260 - auc: 0.5534 - val_loss: 0.6903 - val_binary_accuracy: 0.5303 - val_auc: 0.6379
# Epoch 13/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.6842 - binary_accuracy: 0.5519 - auc: 0.6297 - val_loss: 0.6788 - val_binary_accuracy: 0.5379 - val_auc: 0.8789
# Epoch 14/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.6754 - binary_accuracy: 0.5260 - auc: 0.6616 - val_loss: 0.6580 - val_binary_accuracy: 0.5530 - val_auc: 0.8844
# Epoch 15/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.6630 - binary_accuracy: 0.6364 - auc: 0.6944 - val_loss: 0.6234 - val_binary_accuracy: 0.8258 - val_auc: 0.8881
# Epoch 16/50
# 10/10 [==============================] - 0s 30ms/step - loss: 0.6607 - binary_accuracy: 0.6299 - auc: 0.6448 - val_loss: 0.5770 - val_binary_accuracy: 0.7955 - val_auc: 0.8877
# Epoch 17/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.6292 - binary_accuracy: 0.6429 - auc: 0.7353 - val_loss: 0.5956 - val_binary_accuracy: 0.8182 - val_auc: 0.8866
# Epoch 18/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.5827 - binary_accuracy: 0.7305 - auc: 0.7848 - val_loss: 0.4765 - val_binary_accuracy: 0.8258 - val_auc: 0.8858
# Epoch 19/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.5567 - binary_accuracy: 0.7175 - auc: 0.7730 - val_loss: 0.4820 - val_binary_accuracy: 0.8485 - val_auc: 0.8923
# Epoch 20/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.4626 - binary_accuracy: 0.8149 - auc: 0.8645 - val_loss: 0.4453 - val_binary_accuracy: 0.8258 - val_auc: 0.8947
# Epoch 21/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.4383 - binary_accuracy: 0.8019 - auc: 0.8847 - val_loss: 0.4023 - val_binary_accuracy: 0.8258 - val_auc: 0.8984
# Epoch 22/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.4611 - binary_accuracy: 0.7922 - auc: 0.8638 - val_loss: 0.4005 - val_binary_accuracy: 0.8712 - val_auc: 0.9020
# Epoch 23/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.4366 - binary_accuracy: 0.8117 - auc: 0.8822 - val_loss: 0.4324 - val_binary_accuracy: 0.8409 - val_auc: 0.9038
# Epoch 24/50
# 10/10 [==============================] - 0s 29ms/step - loss: 0.4582 - binary_accuracy: 0.8052 - auc: 0.8683 - val_loss: 0.4218 - val_binary_accuracy: 0.8182 - val_auc: 0.8991
# Epoch 25/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.4371 - binary_accuracy: 0.8247 - auc: 0.8876 - val_loss: 0.4249 - val_binary_accuracy: 0.8712 - val_auc: 0.9032
# Epoch 26/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.4275 - binary_accuracy: 0.8117 - auc: 0.8849 - val_loss: 0.4315 - val_binary_accuracy: 0.8106 - val_auc: 0.8988
# Epoch 27/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3897 - binary_accuracy: 0.8214 - auc: 0.9036 - val_loss: 0.4839 - val_binary_accuracy: 0.8333 - val_auc: 0.9031
# Epoch 28/50
# 10/10 [==============================] - 0s 29ms/step - loss: 0.4119 - binary_accuracy: 0.8149 - auc: 0.8992 - val_loss: 0.4106 - val_binary_accuracy: 0.8182 - val_auc: 0.8992
# Epoch 29/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.4494 - binary_accuracy: 0.8052 - auc: 0.8739 - val_loss: 0.3923 - val_binary_accuracy: 0.8636 - val_auc: 0.9025
# Epoch 30/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.4173 - binary_accuracy: 0.8409 - auc: 0.8982 - val_loss: 0.4041 - val_binary_accuracy: 0.8561 - val_auc: 0.9045
# Epoch 31/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3613 - binary_accuracy: 0.8571 - auc: 0.9220 - val_loss: 0.3805 - val_binary_accuracy: 0.8788 - val_auc: 0.9073
# Epoch 32/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.3537 - binary_accuracy: 0.8539 - auc: 0.9227 - val_loss: 0.4258 - val_binary_accuracy: 0.8409 - val_auc: 0.9122
# Epoch 33/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.4348 - binary_accuracy: 0.8084 - auc: 0.8910 - val_loss: 0.3758 - val_binary_accuracy: 0.8485 - val_auc: 0.9112
# Epoch 34/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.4062 - binary_accuracy: 0.8214 - auc: 0.9087 - val_loss: 0.3964 - val_binary_accuracy: 0.8561 - val_auc: 0.9134
# Epoch 35/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3491 - binary_accuracy: 0.8571 - auc: 0.9309 - val_loss: 0.4074 - val_binary_accuracy: 0.8712 - val_auc: 0.9120
# Epoch 36/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.3566 - binary_accuracy: 0.8571 - auc: 0.9313 - val_loss: 0.3801 - val_binary_accuracy: 0.8258 - val_auc: 0.9139
# Epoch 37/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3655 - binary_accuracy: 0.8442 - auc: 0.9293 - val_loss: 0.3907 - val_binary_accuracy: 0.8409 - val_auc: 0.9199
# Epoch 38/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3894 - binary_accuracy: 0.8312 - auc: 0.9039 - val_loss: 0.3748 - val_binary_accuracy: 0.8333 - val_auc: 0.9165
# Epoch 39/50
# 10/10 [==============================] - 0s 28ms/step - loss: 0.3588 - binary_accuracy: 0.8506 - auc: 0.9188 - val_loss: 0.4375 - val_binary_accuracy: 0.8712 - val_auc: 0.9213
# Epoch 40/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3672 - binary_accuracy: 0.8506 - auc: 0.9222 - val_loss: 0.3842 - val_binary_accuracy: 0.8258 - val_auc: 0.9197
# Epoch 41/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3387 - binary_accuracy: 0.8506 - auc: 0.9315 - val_loss: 0.3716 - val_binary_accuracy: 0.8636 - val_auc: 0.9228
# Epoch 42/50
# 10/10 [==============================] - 0s 27ms/step - loss: 0.3445 - binary_accuracy: 0.8571 - auc: 0.9279 - val_loss: 0.3805 - val_binary_accuracy: 0.8636 - val_auc: 0.9228
# Epoch 43/50
# 10/10 [==============================] - 0s 29ms/step - loss: 0.3386 - binary_accuracy: 0.8701 - auc: 0.9264 - val_loss: 0.3765 - val_binary_accuracy: 0.8561 - val_auc: 0.9234
# Epoch 44/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3458 - binary_accuracy: 0.8539 - auc: 0.9268 - val_loss: 0.3756 - val_binary_accuracy: 0.8636 - val_auc: 0.9234
# Epoch 45/50
# 10/10 [==============================] - 0s 23ms/step - loss: 0.3676 - binary_accuracy: 0.8377 - auc: 0.9234 - val_loss: 0.3709 - val_binary_accuracy: 0.8636 - val_auc: 0.9243
# Epoch 46/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3562 - binary_accuracy: 0.8442 - auc: 0.9221 - val_loss: 0.3517 - val_binary_accuracy: 0.8409 - val_auc: 0.9264
# Epoch 47/50
# 10/10 [==============================] - 0s 29ms/step - loss: 0.3223 - binary_accuracy: 0.8409 - auc: 0.9365 - val_loss: 0.3611 - val_binary_accuracy: 0.8561 - val_auc: 0.9252
# Epoch 48/50
# 10/10 [==============================] - 0s 24ms/step - loss: 0.3438 - binary_accuracy: 0.8377 - auc: 0.9268 - val_loss: 0.3642 - val_binary_accuracy: 0.8485 - val_auc: 0.9251
# Epoch 49/50
# 10/10 [==============================] - 0s 26ms/step - loss: 0.3229 - binary_accuracy: 0.8636 - auc: 0.9372 - val_loss: 0.3544 - val_binary_accuracy: 0.8636 - val_auc: 0.9262
# Epoch 50/50
# 10/10 [==============================] - 0s 25ms/step - loss: 0.2949 - binary_accuracy: 0.8799 - auc: 0.9470 - val_loss: 0.3499 - val_binary_accuracy: 0.8636 - val_auc: 0.9310
#
# Confusion matrix:
#  [[54  8]
#  [10 60]]
#
# F1 Score: 0.8695652173913043

# %%
y_pred = model_nn.predict(df_clean[attr])

# %%
(np.round(y_pred) == df_clean[cl]).value_counts()
# Out:
# Bankrupt?
# True         5615
# False        1204
# dtype: int64

# %%
metrics.confusion_matrix(np.round(y_pred), df_clean[cl])
# Out:
# array([[5415,   20],
#        [1184,  200]], dtype=int64)

# %%
metrics.f1_score(np.round(y_pred), df_clean[cl])
# Out:
# 0.24937655860349128

# %% [markdown]
# # What's next?

# %%
    * DBSCAN
    * Feature Selection
    *
